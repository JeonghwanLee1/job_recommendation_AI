# %%
import pandas as pd

# %%
job_companies = pd.read_csv('data/job_companies.csv')
job_tags = pd.read_csv('data/job_tags.csv')
tags = pd.read_csv('data/tags.csv')
train = pd.read_csv('data/train.csv')
user_tags = pd.read_csv('data/user_tags.csv')

# %%
tag_keyword = {}
for i,row in tags.iterrows():
    tag_keyword[row['tagID']] = row['keyword']

# %%
avg_sizes = []
job_company = {}
for i,row in job_companies.iterrows():
    sizes = str(row['companySize']).split("-")
    avg_size = -1
    if len(sizes)>1:
        avg_size = (int(sizes[0])+int(sizes[1]))/2
    avg_sizes.append(avg_size)
    job_company[row['jobID']] = row['companyID']
    

job_companies['companySize'] = avg_sizes    
job_companies.head()
# Out:
#                           companyID                             jobID  \
# 0  00411460f7c92d2124a67ea0f4cb5f85  e5f6ad6ce374177eef023bf5d0c018b6
# 1  1905aedab9bf2477edc068a355bba31a  185e65bc40581880c4f2c82958de8cfe
# 2  89fcd07f20b6785b92134bd6c1d0fa42  0537fb40a68c18da59a35c2bfe1ca554
# 3  acf4b89d3d503d8252c9c4ba75ddbf6d  b7ee6f5f9aa5cd17ca1aea43ce848496
# 4  fb7b9ffa5462084c5f4e7e85a093e6d7  efe937780e95574250dabe07151bdc23
#
#    companySize
# 0         -1.0
# 1         30.5
# 2        150.5
# 3          5.5
# 4         -1.0

# %%
jobs_tags = {}
for i,row in job_tags.iterrows():
    if row['jobID'] in jobs_tags:
        jobs_tags[row['jobID']].append(tag_keyword[row['tagID']])
    else:
        jobs_tags[row['jobID']] = [tag_keyword[row['tagID']]]
print(jobs_tags)
# Out:
# {'320722549d1751cf3f247855f937b982': ['Ruby', 'Ruby on Rails'], 'e744f91c29ec99f0e662c9177946c627': ['Node.js', 'JavaScript', 'Git'], 'e820a45f1dfc7b95282d10b6087e11c0': ['HTML', 'Vue.js', 'AngularJS', 'JavaScript', 'CSS', 'ReactJS'], '53c3bce66e43be4f209556518c2fcb54': ['Apache Spark', 'Apache Hadoop'], 'fd06b8ea02fe5b1c2496fe1700e9d16c': ['Django', 'Docker', 'AWS EC2', 'JavaScript', 'BitBucket', 'Python', 'Node.js', 'PostgreSQL', 'Git', 'Redis'], '6e7d2da6d3953058db75714ac400b584': ['Java', 'SQL', 'Node.js', 'TypeScript', 'Webpack', 'REST API', 'MySQL', 'Amazon Web Services(AWS)', 'ExpressJS', 'Angular'], '818f4654ed39a1c147d1e51a00ffb4cb': ['Webpack', 'ReactJS', 'TypeScript', 'Git', 'Node.js', 'ES6', 'JavaScript', 'Next.js', 'Redux-Saga'], '019d385eb67632a7e958e23f24bd07d7': ['Python'], '8757150decbd89b0f5442ca3db4d0e0e': ['Java', 'Spring Boot', 'JavaScript', 'Ionic', 'ES6', 'Angular'], '3871bd64012152bfb53fdf04b401193f': ['CSS', 'JavaScript', 'React Native', 'HTML'], '1651cf0d2f737d7adeab84d339dbabd3': ['ReactJS', 'jQuery', 'Vue.js', 'CSS', 'AngularJS', 'Node.js', 'JavaScript', 'Sass(SCSS)', 'HTML'], '7f975a56c761db6506eca0b37ce6ec87': ['Ruby on Rails', 'Redis', 'PostgreSQL', 'Python', 'Nginx', 'Amazon Web Services(AWS)'], '66808e327dc79d135ba18e051673d906': ['ES6', 'GraphQL', 'Vue.js', 'Docker'], '50c3d7614917b24303ee6a220679dab3': ['Kubernetes', 'Shell Script', 'Go', 'Linux', 'Docker', 'Node.js', 'Java'], '884ce4bb65d328ecb03c598409e2b168': ['ReactJS', 'JavaScript', 'Python'], 'b5b41fac0361d157d9673ecb926af5ae': ['Android', 'C#', 'Git', 'iOS', 'Unity', 'Jenkins'], 'ce5140df15d046a66883807d18d0264b': ['JavaScript', 'ReactJS', 'React Native', 'GraphQL', 'Node.js', 'Linux', 'PostgreSQL'], '96b9bff013acedfb1d140579e2fbeb63': ['Node.js', 'Python', 'Apache', 'ExpressJS', 'Django', 'AWS Backup', 'Nginx'], 'dc912a253d1e9ba40e2c597ed2376640': ['CSS', 'JavaScript', 'HTML'], '24146db4eb48c718b84cae0a0799dcfc': ['Java', 'Apache Kafka', 'Tensorflow', 'Keras', 'Python', 'Spring', 'Docker', 'PyTorch'], 'a8ecbabae151abacba7dbde04f761c37': ['HTML5', 'ReactJS', 'Redux-Saga', 'JavaScript', 'jQuery', 'Electron'], 'c60d060b946d6dd6145dcbad5c4ccf6f': ['Node.js', 'HTML', 'ReactJS', 'MySQL', 'Docker', 'CSS'], 'e5e63da79fcd2bebbd7cb8bf1c1d0274': ['HTML', 'Node.js', 'ReactJS', 'JavaScript', 'CSS', 'jQuery', 'Vue.js'], '15d4e891d784977cacbfcbb00c48f133': ['Vue.js', 'RabbitMQ', 'PHP', 'AngularJS', 'AWS RDS', 'Ubuntu', 'JavaScript', 'Python', 'React Native', 'Redis', 'MySQL'], '65cc2c8205a05d7379fa3a6386f710e1': ['JavaScript', 'Docker', 'Kotlin', 'Spring Boot'], '851ddf5058cf22df63d3344ad89919cf': ['Ruby', 'JavaScript', 'Aurora DB', 'Vue.js', 'GitHub', 'Sass(SCSS)', 'AWS ElasticBeanstalk', 'MySQL', 'Ruby on Rails'], 'e0c641195b27425bb056ac56f8953d24': ['MySQL', 'Java', 'MongoDB', 'Node.js', 'OOP', 'Linux', 'Python', 'PHP', 'ReactJS', 'Git', 'JavaScript'], '2bcab9d935d219641434683dd9d18a03': ['CSS', 'HTML', 'ES6'], '26e359e83860db1d11b6acca57d8ea88': ['Apache Spark', 'Scala', 'SQL', 'Python'], 'ab817c9349cf9c4f6877e1894a1faa00': ['iOS', 'JavaScript', 'Java', 'Swift'], '25df35de87aa441b88f22a6c2a830a17': ['AWS X-Ray', 'Flask', 'Memcached', 'Django', 'Redis', 'AWS DynamoDB'], '9cc138f8dc04cbf16240daa92d8d50e2': ['Oracle', 'Spring', 'MySQL', 'Java'], 'cbcb58ac2e496207586df2854b17995f': ['Mocha', 'CSS', 'Linux', 'REST API', 'Node.js', 'ExpressJS', 'HTML', 'AWS Lambda', 'MySQL', 'JavaScript'], '82b8a3434904411a9fdc43ca87cee70c': ['TypeScript', 'React Native', 'GCP(Google Cloud Platform)', 'JavaScript', 'Azure'], '1e6e0a04d20f50967c64dac2d639a577': ['JavaScript', 'HTML', 'Ruby on Rails', 'CSS'], 'afd4836712c5e77550897e25711e1d96': ['NoSQL', 'Amazon Web Services(AWS)', 'Python', 'MySQL', 'REST API', 'Node.js'], 'c4ca4238a0b923820dcc509a6f75849b': ['Redis', 'Ruby', 'Elasticsearch', 'Ruby on Rails'], '142949df56ea8ae0be8b5306971900a4': ['Ruby on Rails', 'Spring Boot', 'Git', 'PHP', 'Vue.js', 'Node.js', 'Spring', 'Java'], '0b8aff0438617c055eb55f0ba5d226fa': [' ...

# %%
size_tech = {'none':{}, 'small':{},'medium':{},'big':{}}    #Nan, 0~10, 11~100, 100~
size_class = []
company_size = {}
for i, row in job_companies.iterrows():
    techs = jobs_tags[row['jobID']]
    companySize = row['companySize']
    
    if companySize<0:
        size_class.append(0)
    elif companySize<10:
        size_class.append(1)
    elif companySize<100:
        size_class.append(2)
    else:
        size_class.append(3)
    
    company_size[row['companyID']] = size_class[i]
    
    for tech in techs: 
        if companySize<0:    #NaN
            if tech in size_tech['none']:
                size_tech['none'][tech]+=1
            else:
                size_tech['none'][tech]=1

        elif companySize<10:    #small
            if tech in size_tech['small']:
                size_tech['small'][tech]+=1
            else:
                size_tech['small'][tech]=1

        elif companySize<100:
            if tech in size_tech['medium']:
                size_tech['medium'][tech]+=1
            else:
                size_tech['medium'][tech]=1

        else:
            if tech in size_tech['big']:
                size_tech['big'][tech]+=1
            else:
                size_tech['big'][tech]=1

job_companies['size_class'] = size_class
for key in size_tech.keys():
    size_tech[key] = sorted(size_tech[key].items(),key=lambda x:x[1],reverse=True)

# %%
user_tech = {}

for i,row in user_tags.iterrows():
    userID = row['userID']
    tag = tag_keyword[row['tagID']]
    if userID in user_tech:
        user_tech[userID].add(tag)
    else:
        user_tech[userID] = set([tag])

# %%
wgraph = {}
for row in user_tech.items():
    lrow = list(row[1])
    for i in range(len(lrow)):
        if lrow[i] in wgraph:
            for j in range(i+1,len(lrow)):
                if lrow[j] in wgraph[lrow[i]]:
                    wgraph[lrow[i]][lrow[j]]+=1
                else:
                    wgraph[lrow[i]][lrow[j]]=1
        else:
            wgraph[lrow[i]] = {}
            for j in range(i+1,len(lrow)):
                if lrow[j] in wgraph[lrow[i]]:
                    wgraph[lrow[i]][lrow[j]]+=1
                else:
                    wgraph[lrow[i]][lrow[j]]=1
for key in wgraph.keys():
    wgraph[key] = sorted(wgraph[key].items(),key=lambda x:x[1],reverse=True)
print(wgraph)
# Out:
# {'Spring Cloud': [('MQTT', 1), ('Naver Cloud Platform', 1), ('JUnit', 1), ('Redis', 1), ('Jenkins', 1), ('Apache Kafka', 1), ('JavaScript', 1), ('Zuul', 1), ('WebSocket', 1), ('MyBatis', 1), ('Spring Data JPA', 1), ('Git', 1), ('Java', 1), ('Regular expression', 1), ('Spring', 1), ('i18n', 1), ('Vuex', 1), ('MariaDB', 1), ('ES6', 1), ('OAuth', 1), ('Vue.js', 1), ('Spring Boot', 1), ('GitHub', 1), ('Docker', 1), ('Apache Subversion(SVN)', 1)], 'MQTT': [('Git', 4), ('JavaScript', 3), ('Spring', 3), ('Jenkins', 2), ('MyBatis', 2), ('Java', 2), ('MariaDB', 2), ('Vue.js', 2), ('Spring Boot', 2), ('Docker', 2), ('SQLite', 2), ('Raspberry Pi', 2), ('Android', 2), ('MongoDB', 2), ('Naver Cloud Platform', 1), ('JUnit', 1), ('Redis', 1), ('Apache Kafka', 1), ('Zuul', 1), ('WebSocket', 1), ('Spring Data JPA', 1), ('Regular expression', 1), ('i18n', 1), ('Vuex', 1), ('ES6', 1), ('OAuth', 1), ('GitHub', 1), ('Apache Subversion(SVN)', 1), ('C', 1), ('C++', 1), ('ExpressJS', 1), ('RabbitMQ', 1), ('Amazon Web Services(AWS)', 1), ('AWS Lambda', 1), ('AWS API Gateway', 1), ('OpenCV', 1), ('Apache Cordova', 1), ('MySQL', 1), ('Arduino', 1), ('Node.js', 1), ('ReactJS', 1), ('AWS IAM', 1), ('TypeScript', 1), ('Couchbase Server', 1), ('JIRA', 1), ('Oracle Database', 1), ('Apache Tomcat', 1), ('CSS', 1), ('Retrofit', 1), ('JDBC(Java Database Connectivity)', 1), ('Ajax', 1), ('jQuery', 1), ('HTML5', 1), ('UML', 1), ('Django', 1), ('Apache Ant', 1), ('DRF(Django REST framework)', 1), ('JSP', 1), ('Python', 1), ('Oracle', 1)], 'Naver Cloud Platform': [('Spring', 3), ('JavaScript', 2), ('Spring Data JPA', 2), ('Java', 2), ('ES6', 2), ('GitHub', 2), ('Docker', 2), ('JUnit', 1), ('Redis', 1), ('Jenkins', 1), ('Apache Kafka', 1), ('Zuul', 1), ('WebSocket', 1), ('MyBatis', 1), ('Git', 1), ('Regular expression', 1), ('i18n', 1), ('Vuex', 1), ('MariaDB', 1), ('OAuth', 1), ('Vue.js', 1), ('Spring Boot', 1), ('Apache Subversion(SVN)', 1), ('Kubernetes', 1), ('Keras', 1), ('Swift', 1), ('SQLAlchemy', 1), ('Google Cloud Firestore', 1), ('Jupyter', 1), ('Pandas', 1), ('Swagger', 1), ('OpenCV', 1), ('Seaborn', 1), ('Python', 1), ('Google Compute Engine', 1), ('Tensorflow', 1), ('Google App Engine', 1), ('Elasticsearch', 1), ('Celery', 1), ('C++', 1), ('Bootstrap', 1), ('CSS', 1), ('HTML', 1), ('Firebase', 1), ('Ruby', 1), ('Ajax', 1), ('Android', 1), ('MySQL', 1), ('Trello', 1), ('ReactJS', 1), ('XML', 1), ('Vanilla JS', 1), ('Ruby on Rails', 1)], 'JUnit': [('Spring', 9), ('MySQL', 7), ('Spring Data JPA', 6), ('Java', 6), ('Spring Boot', 6), ('JavaScript', 4), ('WebSocket', 4), ('MyBatis', 4), ('GitHub', 4), ('Bootstrap', 4), ('Redis', 3), ('Apache Subversion(SVN)', 3), ('HTML', 3), ('Linux', 3), ('JPA(Java Persistent API)', 3), ('Jenkins', 2), ('Git', 2), ('i18n', 2), ('MariaDB', 2), ('ES6', 2), ('OAuth', 2), ('Vue.js', 2), ('Docker', 2), ('CSS', 2), ('Node.js', 2), ('Java Persistence API', 2), ('Apache Tomcat', 2), ('Django', 2), ('Mockito', 2), ('jQuery', 2), ('JSP', 2), ('ReactJS', 2), ('Redux.js', 2), ('Apache Kafka', 1), ('Zuul', 1), ('Regular expression', 1), ('Vuex', 1), ('Moment.js', 1), ('Unity', 1), ('C#', 1), ('GitLab', 1), ('AWS CodeDeploy', 1), ('JDBC(Java Database Connectivity)', 1), ('HTML5', 1), ('Spring Security', 1), ('Swagger', 1), ('AWS IAM', 1), ('Shell Script', 1), ('Couchbase', 1), ('Machine Learning', 1), ('RabbitMQ', 1), ('Elasticsearch', 1), ('NLP', 1), ('JIRA', 1), ('json', 1), ('React Native', 1), ('Apache HTTP Server', 1), ('Android', 1), ('mybatis', 1), ('Raspberry Pi', 1), ('Apache POI', 1), ('AWS RDS', 1), ('AWS Elastic Load Balancing', 1), ('Python', 1), ('공공데이터', 1), ('Arduino', 1), ('SQLite', 1), ('JWT', 1), ('ESLint', 1), ('web3.js', 1), ('ExpressJS', 1), ('AWS Elastic Beanstalk', 1), ('Jest', 1), ('Webpack', 1), ('Ajax', 1), ('RxJava', 1), ('RxJS', 1), ('SockJS', 1), ('Logback', 1), ('Babel', 1), ('Next.js', 1), ('MetaMask', 1), ('Solidity', 1), ('Tableau', 1), ('Sass(SCSS)', 1), ('Ethereum', 1), ('TypeScript', 1), ('Yarn', 1), ...

# %%
count = 0
for elem in user_tech.items():
    print(list(elem[1]))
# Out:
# ['Spring Cloud', 'MQTT', 'Naver Cloud Platform', 'JUnit', 'Redis', 'Jenkins', 'Apache Kafka', 'JavaScript', 'Zuul', 'WebSocket', 'MyBatis', 'Spring Data JPA', 'Git', 'Java', 'Regular expression', 'Spring', 'i18n', 'Vuex', 'MariaDB', 'ES6', 'OAuth', 'Vue.js', 'Spring Boot', 'GitHub', 'Docker', 'Apache Subversion(SVN)']
# ['.NET', 'MVC', 'Linux', 'Raspberry Pi', 'Tensorflow', 'Android', 'IoT', 'Python']
# ['Oracle', 'Java', 'MSSQL(Microsoft SQL Server)', 'JSP', 'MyBatis', 'Git', 'JIRA']
# ['centOS', 'Spring Batch', 'Shell Script', 'RabbitMQ', 'Redis', 'Apache Subversion(SVN)', 'Spring', 'Jenkins', 'Shell', 'PostgreSQL']
# ['Travis CI', 'AWS S3', 'AWS EC2', 'Heroku', 'Nginx', 'Ubuntu', 'CSS3', 'Redis', 'MongoDB Atlas', 'Vanilla JS', 'Bootstrap', 'Passport.js', 'MongoDB', 'TensorFlow.js', 'Sequelize.js', 'ExpressJS', 'React Hooks API', 'AWS ElasticBeanstalk', 'Socket.IO', 'AWS CloudWatch', 'Pug', 'Git', 'HTML5', 'AWS ElastiCache', 'AWS RDS', 'MySQL', 'Material-UI', 'OAuth', 'Node.js', 'JWT', 'ReactJS', 'GitHub', 'Mongoose', 'WebRTC']
# ['JavaScript', 'YOLO', 'C++', 'CSS3', 'Flask', 'OpenCV', 'Java Servlet', 'HTML5', 'Python']
# ['CSS', 'HTML', 'JavaScript', 'Numpy', 'Google Cloud Datalab', 'Node.js', 'Selenium', 'Scikit-Learn', 'React Native', 'ReactJS', 'CSS3', 'HTML5', 'R', 'MongoDB', 'Pandas', 'Python']
# ['C#', 'ASP.NET', 'Java', 'MSSQL(Microsoft SQL Server)', 'JSP', 'Design Pattern', 'Apache', 'Android', 'Microsoft IIS', 'Apache Tomcat', 'C++']
# ['CSS', 'JavaScript', 'Oracle', 'Java', 'Node.js', 'JSP', 'Spring']
# ['JavaScript', 'Kotlin', 'Java', 'Node.js', 'Android']
# ['JavaScript', 'Azure Dedicated HSM', 'AWS EC2', 'Linux', 'WordPress', 'CodeIgniter', 'CSS3', 'jQuery', 'Bootstrap', 'PHP', 'HTML5', 'PostgreSQL', 'MySQL']
# ['REST API', 'Spring Boot', 'Java', 'MSSQL(Microsoft SQL Server)', 'GitHub', 'Querydsl', 'Spring', 'Spring Data JPA', 'MySQL']
# ['Naver Map API', 'REST API', 'AWS S3', 'AWS EC2', 'WordPress', 'Nuxt.js', 'Glide', 'ESLint', 'Jenkins', 'Sequelize.js', 'ExpressJS', 'JavaScript', 'Firebase', 'jQuery', 'Android', 'PHP', 'KakaoLink API', 'PWA(Progressive Web App)', 'Java', 'Vuetify.js', 'AWS RDS', 'Vuex', 'MariaDB', 'ES6', 'MySQL', 'Trello', 'Vue.js', 'Spring Boot', 'Node.js', 'Slack API', 'ReactJS', 'GitHub', 'JIRA']
# ['ExpressJS', 'JavaScript', 'Django', 'Redux-Saga', 'Node.js', 'ReactJS', 'Next.js', 'ES6', 'Redux.js', 'Pug', 'MongoDB', 'PostgreSQL', 'MySQL']
# ['AWS S3', 'Heroku', 'Nginx', 'Apollo Server', 'Bootstrap', 'MongoDB', 'CSS', 'HTML', 'JavaScript', 'Jest', 'Webpack', 'Apollo Client', 'Git', 'styled-components', 'Babel', 'GraphQL', 'Sass(SCSS)', 'Node.js', 'ReactJS', 'DigitalOcean', 'GitHub']
# ['CSS3', 'Bootstrap', 'Angular', 'CSS', 'HTML', 'JavaScript', 'Firebase', 'jQuery', 'Google Cloud Firestore', 'Android', 'Java Servlet', 'HTML5', 'Java', 'Linux', 'JSP', 'MariaDB', 'SQLite', 'Node.js', 'TypeScript', 'XML']
# ['REST API', 'AngularJS', 'CSS3', 'C', 'ESLint', 'Bootstrap', 'C++', 'JavaScript', 'Webpack', 'Ajax', 'jQuery', 'Android', 'Java Servlet', 'HTML5', 'Java', 'JSP', 'Babel', 'Spring', 'ES6', 'Python', 'MySQL', 'Arduino', 'Vue.js', 'Node.js', 'ReactJS', 'XML', 'WebRTC']
# ['JavaScript', 'Vue.js', 'Spring Boot', 'Java', 'Jsoup', 'AWS EC2', 'Node.js', 'Ajax', 'ReactJS', 'jQuery', 'Axios', 'MySQL']
# ['Angular Material', 'TypeScript', 'Angular']
# ['C#', 'C', '소켓', 'ncurses', 'Android', 'Shell', 'MySQL']
# ['AWS S3', 'AWS EC2', 'Nginx', 'Nuxt.js', 'MQTT', 'C', 'C++', 'ExpressJS', 'JavaScript', 'Git', 'RabbitMQ', 'Amazon Web Services(AWS)', 'AWS Lambda', 'AWS API Gateway', 'OpenCV', 'MariaDB', 'Apache Cordova', 'MySQL', 'Arduino', 'Vue.js', 'SQLite', 'Node.js', 'ReactJS', 'AWS IAM', 'TypeScript', 'Couchbase Server', 'JIRA']
# ['JavaScript', 'Spring Boot', 'Java', 'Node.js', 'Webpack', 'ReactJS', 'Redux.js', 'TypeScript', 'Google Maps API', 'Apache', 'Android', 'MongoDB']
# ['Vue.js', 'PHP', 'Java', 'Node.js', 'JSP', 'iOS', 'Laravel', 'Google AI Hub', 'Android', 'Responsive Web', 'WebRTC']
# ['Vue.js', 'Spring Security', 'H2 Database', 'Spring Boot', 'Java', 'JWT', 'JUnit', 'Spring', 'Spring Data JPA', 'Moment.js', 'MySQL']
# ['C#', 'Adobe Photoshop', 'Adobe Premiere', 'Blender', 'Unity']
# ['Java', 'Linux', 'WebtoB', 'Nginx', 'Jeus', 'Jenkins', 'Apache HTTP Server', 'Spring', 'Apache Tomcat']
# ['Apache Maven', 'REST API', 'GatsbyJS', 'AWS EC2', 'Bootstrap', 'MongoDB', 'ExpressJS', 'JavaScript', 'jQuery', 'MyBatis', 'Spring Security', 'Java', 'Kendo UI', 'Chart.js', 'JSP', 'Vuetify.js', 'Spring', 'AWS RDS', 'Vuex', 'ES6', 'MySQL', 'GraphQL', 'Vue.js', 'Sass(SCSS)', 'Redux-Saga', 'Node.js', 'ReactJS', 'Redux.js', 'PostgreSQL']
# ['ExpressJS', 'JavaScript', 'Solidity', 'Node.js', 'jQuery', 'MongoDB Atlas', 'Mongoose']
# ['CSS', 'HTML', 'JavaScript']
# ['JavaScript', 'Arduino', 'Django', 'Selenium', 'Node.js', 'Linux', 'Ubuntu', 'DRF(Django REST framework)', 'CSS3', 'BeautifulSoup', 'Raspberry Pi', 'Tensorflow', 'Bootstrap', 'HTML5', 'Python']
# ['JavaScript', 'Shell Script', 'Java', 'PHP', 'ASP', 'MySQL']
# ['JavaScript', 'AWS EC2', 'Node.js', 'Heroku', 'ReactJS', 'AWS DynamoDB', 'JSP', 'AWS Lambda', 'Spring', 'Unity', 'MongoDB', 'Ruby on Rails']
# ['CSS', 'HTML', 'JavaScript', 'Oracle', 'Java', 'Node.js', 'JSP', 'jQuery', 'MyBatis', 'Spring', 'MongoDB', 'Java Servlet', 'HTML5', 'MySQL']
# ['JavaScript', 'Java', 'Node.js', 'CSS3', 'ReactJS', 'JSP', 'C', 'PHP', 'HTML5', 'C++']
# ['Hibernate', 'JUnit', 'Redis', 'Bootstrap', 'Jenkins', 'CSS', 'HTML', 'JavaScript', 'Unity', 'Java', 'Linux', 'JPA(Java Persistent API)', 'Spring', 'MySQL', 'C#', 'GitLab', 'Vue.js', 'Spring Boot', 'Node.js', 'Docker']
# ['Trello', 'BitBucket', 'AWS Route 53', 'AWS S3', 'AWS EC2', 'Slack API', 'Node.js', 'AWS Elastic Load Balancing', 'Zeplin', 'AWS DynamoDB', 'AWS Lambda', 'GitHub', 'TypeScript', 'AWS API Gateway', 'React Native', 'AWS RDS', 'MySQL']
# ['Verilog', 'Vue.js', 'Spring Boot', 'Vue CLI', 'Java', 'C++', 'Swagger', 'MFC', 'OpenCV', 'MariaDB', 'MySQL']
# ['Vagrant', 'AWS S3', 'AWS EC2', 'Nginx', 'Ubuntu', 'TypeORM', 'Apollo Server', 'Bootstrap', 'Shell', 'ExpressJS', 'JavaScript', 'Composer', 'Shell Script', 'WebSocket', 'PHP', 'Android', 'Git', 'HTML5', 'AWS Lambda', 'MariaDB', 'AWS Lightsail', 'MySQL', 'Python', 'Trello', 'GraphQL', 'NoSQL', 'Node.js', 'ReactJS', 'FCM(Firebase Cloud Messaging)', 'GitHub', 'TypeScript', 'Handlebars.js', 'JIRA']
# ['C#', 'centOS', 'C++', 'Java', 'Linux', 'Oracle', 'MSSQL(Microsoft SQL Server)', 'Qt', 'AWS EC2', 'C', 'Spring', 'MySQL']
# ['CSS', 'HTML', 'JavaScript', 'Vue.js', 'Django', 'Sass(SCSS)', 'Nuxt.js', 'CSS3', 'ReactJS', 'jQuery', 'PHP', 'Vuex', 'HTML5', 'MySQL']
# ['centOS', 'BitBucket', 'Spring Data JPA', 'GitLab', 'SQLite', 'Java', 'Jenkins', 'MQTT', 'Raspberry Pi', 'Docker', 'Spring', 'Android', 'Git', 'MongoDB', 'Oracle Database']
# ['HTML', 'JavaScript', 'Java', 'JSP', 'Spring', 'Java Servlet']
# ['Python', 'Google API', 'GitLab', 'Protocol Buffers', 'Vue.js', 'SQLite', 'Java', 'Spring Boot', 'REST API', 'gRPC', 'Django', 'Firebase', 'GitHub', 'JIRA', 'MariaDB', 'Vuetify.js', 'MySQL']
# ['JavaScript', 'Django', 'Angular Material', 'CSS3', 'Amazon Web Services(AWS)', 'Angular', 'GitHub', 'TypeScript', 'Git', 'HTML5', 'ES6', 'Python']
# ['ExpressJS', 'JavaScript', 'Arduino', 'Spring Boot', 'PHP', 'Java', 'AWS EC2', 'Node.js', 'GitHub', 'AWS RDS', 'Android', 'Git', 'MySQL']
# ['Kotlin', 'Vue.js', 'Vue CLI', 'Java', 'Node.js', 'Webpack', 'FCM(Firebase Cloud Messaging)', 'Raspberry Pi', 'C', 'Android', 'TCP/IP', 'MariaDB']
# ['JavaScript', 'Java', 'AWS EC2', 'Bootstrap', 'Google Maps API', 'Spring', 'Android', 'HTML5', 'MySQL']
# ['C#', 'JavaScript', 'ASP.NET', 'Apache Maven', 'Hibernate', 'Java', 'MSSQL(Microsoft SQL Server)', 'Git', 'MySQL']
# ['JavaScript', 'Java', 'KakaoTalk API', 'Google Geolocation API', 'ibatis', 'JavaFX', 'JSP', 'Apache Tiles', 'Apache Struts', 'Android', 'Spring', 'PHP', 'Apache Tomcat', 'MariaDB']
# ['Bootstrap', 'JavaScript', 'Firebase', 'Ajax', 'jQuery', 'Java Persistence API', 'MyBatis', 'Java', 'Amazon Web Services(AWS)', 'JSP', 'Next.js', 'Axios', 'Spring', 'Elasticsearch', 'Vuex', 'MariaDB', 'Python', 'MySQL', 'Vue.js', 'Spring Boot', 'Node.js', 'Google Analytics', 'ReactJS', 'Redux.js']
# ['Java', 'Node.js', 'MVC', 'Ajax', 'JSP', 'Bootstrap', 'Socket.IO', 'MyBatis', 'Spring', 'AWS RDS', 'MySQL']
# ['CSS', 'HTML', 'JavaScript', 'C++', 'SQL', 'Node.js', 'Java', 'Socket.IO', 'Android', 'MySQL']
# ['C#', 'JavaScript', 'Firebase', 'REST API', 'AWS EC2', 'Nginx', 'Swift', 'MySQL', 'Photon', 'iOS', 'Unity', 'PHP', 'AR', 'Google App Engine']
# ['Node.js', 'jQuery', 'Puppeteer', 'Spring', 'FxJS']
# ['Solidity', 'Arduino', 'Java', 'Node.js', 'Webpack', 'konlpy', 'beautifulsoup', 'Flask', 'Raspberry Pi', 'Klaytn', 'Tensorflow', 'Bootstrap', 'MariaDB', 'Python']
# ['JDBC(Java Database Connectivity)', 'Java', 'Ajax', 'Spring', 'Apache Tomcat', 'Vanilla JS', 'MySQL']
# ['JavaScript', 'Arduino', 'Java', 'Node.js', 'ReactJS', 'Jeus', 'JSP', 'Cocos2d', 'Swing', 'Lua', 'Bootstrap', 'Apache Tomcat', 'Unity', 'Java Servlet', 'Oracle Database', 'Spring']
# ['Vue.js', 'Travis CI', 'Django', 'Java', 'Selenium', 'Node.js', 'Mocha', 'JNI(Java Native Interface)', 'C', 'Semantic UI', 'Chai', 'MongoDB', 'MariaDB', 'Vanilla JS', 'PostgreSQL']
# ['AWS S3', 'AWS EC2', 'Hibernate', 'Algolia', 'Laravel', 'Bootstrap', 'Sequelize.js', 'CSS', 'ExpressJS', 'HTML', 'Retrofit', 'Go', 'PHP', 'Git', 'Java', 'JPA(Java Persistent API)', 'Spring', 'AWS RDS', 'MariaDB', 'MySQL', 'Python', 'Vue.js', 'Sass(SCSS)', 'Node.js', 'ReactJS']
# ['C#', 'Vue.js', 'Akka.NET', 'Flask', 'Python']
# ['JavaScript', 'D3.js', 'MVC', 'Java', 'JWT', 'Google Geolocation API', 'Ajax', 'Naver Clova API', 'Raspberry Pi', 'Android', 'PHP', 'Python']
# ['Node.js', 'ReactJS', 'MySQL', 'TypeScript', 'Docker', 'Kubernetes', 'Elastic Stack']
# ['JavaScript', 'Kotlin', 'Spring Security', 'Spring Boot', 'Oracle', 'Java', 'D3.js', 'C++', 'ArcMap', 'Thymeleaf', 'MFC', 'Apache Subversion(SVN)', 'MyBatis', 'Spring', 'Android', 'MySQL']
# ['Gradle', 'Apache Maven', 'REST API', 'AWS S3', 'Travis CI', 'AWS EC2', 'Nginx', 'AWS CLI(AWS Command Line Interface)', 'CSS3', 'JUnit', 'Bootstrap', 'AWS CodeDeploy', 'JDBC(Java Database Connectivity)', 'MyBatis', 'Spring Data JPA', 'HTML5', 'Spring Security', 'Java', 'Linux', 'Swagger', 'Spring', 'MariaDB', 'MySQL', 'OAuth', 'Spring Boot', 'AWS IAM', 'GitHub']
# ['JavaScript', 'Spring Security', 'REST API', 'Java', 'SQL', 'AWS EC2', 'Ajax', 'JSP', 'jQuery', 'Spring', 'Android', 'Java Servlet']
# ['CSS', 'ExpressJS', 'HTML', 'JavaScript', 'Solidity', 'Android', 'Django', 'Node.js', 'HTML5', 'DRF(Django REST framework)', 'Socket.IO', 'Tensorflow', 'AWS RDS', 'MongoDB', 'Pandas', 'PostgreSQL', 'MySQL']
# ['Spring Security', 'REST API', 'Java', 'React Native', 'Chrome Extension', 'Ajax', 'ReactJS', 'Thymeleaf', 'CSS3', 'iOS', 'JPA(Java Persistent API)', 'Spring', 'Android', 'HTML5', 'ES6']
# ['JavaScript', 'Vue.js', 'Django', 'Google Cloud APIs', 'ReactJS', 'DRF(Django REST framework)', 'Redux.js', 'Axios', 'PHP', 'Python']
# ['AWS Route 53', 'Python', 'Django', 'AWS EC2', 'Selenium', 'Nginx', 'Ubuntu', 'uWSGI', 'Bootstrap', 'Semantic UI', 'AWS RDS', 'PostgreSQL', 'MySQL']
# ['CSS', 'HTML', 'JavaScript', 'Bootstrap', 'Ruby on Rails']
# ['Python', 'JavaScript', 'C++', 'Shell Script', 'Java', 'C', 'MyBatis', 'Spring', 'PHP', 'Oracle Database', 'MySQL']
# ['GraphQL', 'JavaScript', 'JSX', 'React Hooks API', 'GatsbyJS', 'Node.js', 'ReactJS', 'CSS3', 'HTML5']
# ['Deep Learning', 'Python', 'JavaScript', 'C++', 'Java', 'CSS3', 'OpenGL', 'Tensorflow', 'Spring', 'Apache Tomcat', 'HTML5', 'MySQL']
# ['Bootstrap', 'Google Firebase Realtime Database', 'JavaScript', 'Firebase', 'Ajax', 'AWS ElasticBeanstalk', 'JIRA', 'Google Cloud Firestore', 'Git', 'Google API Analytics', 'Google Dialogflow', 'PWA(Progressive Web App)', 'Django', 'DRF(Django REST framework)', 'Axios', 'Python', 'Vue.js', 'GitLab', 'JWT', 'FCM(Firebase Cloud Messaging)', 'Vuetify.js']
# ['C#', 'JavaScript', 'ASP.NET', 'Linux', 'MySQL', 'Laravel', 'PHP', 'MariaDB', 'HTML5', 'C++']
# ['CSS', 'HTML', 'GraphQL', 'Node.js', 'ReactJS', 'MySQL', 'ROS', 'AWS Lambda', 'Google BigQuery', 'AWS Cognito', 'PHP', 'MongoDB', 'Python']
# ['GraphQL', 'Sass(SCSS)', 'ReactJS', 'styled-components', 'Redux.js', 'TypeScript', 'Git']
# ['AWS S3', 'Logstash', 'Nginx', 'CSS3', 'Apache Spark', 'Apache Tomcat', 'MongoDB', 'JavaScript', 'Apache Hadoop', 'jQuery', 'HTML5', 'Elastic Stack', 'SockJS', 'Kibana', 'centOS', 'Google API', 'Java', 'Apache Hive', 'JSP', 'Spring', 'MySQL', 'Spring Boot', 'Oracle', 'ReactJS', 'Azure']
# ['Spring REST Docs', 'JavaScript', 'Spring Security', 'Spring Boot', 'Oracle', 'CSS3', 'AWS ElasticBeanstalk', 'jQuery', 'MyBatis', 'Spring', 'Spring Data JPA', 'MariaDB', 'HTML5', 'MySQL']
# ['KakaoPay API', 'REST API', 'AWS EC2', 'CSS3', 'Bootstrap', 'CSS', 'JavaScript', 'Ajax', 'jQuery', 'MyBatis', 'Spring Data JPA', 'HTML5', 'Toss API', 'Java', 'JSP', 'JPA(Java Persistent API)', 'Spring', 'AWS RDS', 'MySQL', 'Spring Boot']
# ['AWS S3', 'AWS EC2', 'AngularJS', 'Bootstrap', 'MongoDB', 'CSS', 'ExpressJS', 'HTML', 'JavaScript', 'Webpack', 'AWS DynamoDB', 'jQuery', 'AWS Elastic Transcoder', 'PHP', 'Django', 'AWS Lambda', 'AWS Amplify', 'AWS CloudFront', 'Python', 'MySQL', 'Vue.js', 'Sass(SCSS)', 'Node.js', 'TypeScript', 'AWS Cognito']
# ['Google Cloud Firestore']
# ['Apollo Server', 'MongoDB', 'AWS Elastic Beanstalk', 'ExpressJS', 'HTML', 'JavaScript', 'Jest', 'Socket.IO', 'AWS Lambda', 'CircleCI', 'MariaDB', 'Trello', 'GraphQL', 'Sass(SCSS)', 'Node.js', 'ReactJS', 'GitHub', 'Redux.js', 'Enzyme', 'Mongoose', 'Ruby on Rails']
# ['BitBucket', 'Spring Data JPA', 'JDBC(Java Database Connectivity)', 'Spring Boot', 'REST API', 'Java', 'MVC', 'Node.js', 'Swagger', 'JSP', 'Android', 'Azure Cognitive Services', 'Jenkins', 'Apache Tomcat', 'Java Servlet', 'GCP(Google Cloud Platform)', 'AWS Lightsail', 'MySQL']
# ['CSS', 'ExpressJS', 'HTML', 'JavaScript', 'JDBC(Java Database Connectivity)', 'Arduino', 'Java', 'Heroku', 'Node.js', 'EJS', 'MySQL', 'GitHub', 'Tensorflow', 'Android', 'MongoDB', 'Python']
# ['Gradle', 'Apache Maven', 'Nginx', 'Redis', 'Apache Tomcat', 'Zuul', 'WebSocket', 'MyBatis', 'Spring Data JPA', 'Git', 'Spring Security', 'Java', 'Linux', 'JSP', 'Apache', 'Spring', 'MySQL', 'OAuth', 'Spring Boot', 'Oracle', 'JWT', 'Handlebars.js', 'Apache Subversion(SVN)']
# ['ExpressJS', 'JavaScript', 'Java', 'Node.js', 'ReactJS', 'JSP', 'jQuery', 'MyBatis', 'Spring', 'MongoDB', 'MySQL']
# ['Apache Maven', 'REST API', 'AWS S3', 'Hibernate', 'JSTL', 'C', 'Apache Tomcat', 'Apache Kafka', 'C++', 'CSS', 'HTML', 'JavaScript', 'JDBC(Java Database Connectivity)', 'H2 Database', 'Microservice Architecture', 'MVC', 'Ajax', 'MyBatis', 'Git', 'HTML5', 'Spring Security', 'Java', 'Logback', 'Swagger', 'JSP', 'Regular expression', 'JPA(Java Persistent API)', 'Spring', 'MySQL', 'Spring Boot', 'JWT', 'GitHub', 'Spring Data']
# ['CSS', 'JavaScript', 'Sass(SCSS)', 'Slack API', 'CSS3', 'CodeIgniter', 'Angular', 'GitHub', 'TypeScript', 'PHP', 'Git', 'HTML5', 'MySQL']
# ['REST API', 'Spring Boot', 'Java', 'Ajax', 'JUnit', 'Java Persistence API', 'JPA(Java Persistent API)']
# ['centOS', 'GraphQL', 'JavaScript', 'Java', 'AWS EC2', 'Ubuntu', 'Apollo Client', 'ReactJS', 'JSP', 'jQuery', 'CSS3', 'Vanilla JS', 'Spring', 'Apache Tomcat', 'HTML5', 'MySQL']
# ['CSS3', 'JSTL', 'JSP', 'jQuery', 'Apache Tomcat', 'Java Servlet', 'MariaDB', 'HTML5']
# ['CSS', 'HTML', 'Arduino', 'C++', 'Java', 'jQuery', 'MyBatis', 'Android', 'Spring', 'Bluetooth', 'OpenCV', 'MySQL']
# ['JavaScript', 'Apache Maven', 'Java', 'JSP', 'jQuery', 'MyBatis', 'Bootstrap', 'R']
# ['Spring', 'Java', 'JavaScript', 'MySQL']
# ['JavaScript', 'Spring Batch', 'Spring Security', 'AWS S3', 'Java', 'WebSocket', 'Ajax', 'jQuery', 'MyBatis', 'Spring', 'AWS RDS', 'Oracle Database', 'HTML5']
# ['Mongoose', 'Gradle', 'JavaScript', 'Spring Boot', 'Java', 'Selenium', 'Node.js', 'ReactJS', 'jQuery', 'BeautifulSoup', 'GitHub', 'Socket.IO', 'Redux.js', 'Jenkins', 'MongoDB', 'Vanilla JS', 'Python']
# ['Python', 'Discord.js', 'JavaScript', 'Firebase', 'NestJS', 'Node.js', 'MFC', 'Redis', 'PostgreSQL', 'C++']
# ['CSS', 'Python', 'HTML', 'JavaScript', 'AWS EC2', 'Node.js', 'Java', 'jQuery', 'Raspberry Pi', 'GitHub', 'Google Maps API', 'Bootstrap', 'Android', 'MongoDB', 'Git', 'C++']
# ['ExpressJS', 'JavaScript', 'Node.js', 'CSS3', 'HTML5', 'MySQL']
# ['ExpressJS', 'Arduino', 'AngularJS', 'Android', 'MySQL']
# ['REST API', 'AWS EC2', 'Chrome Extension', 'Ubuntu', 'C', 'MFC', 'Apache Tomcat', 'MongoDB', 'C++', 'CSS', 'ExpressJS', 'HTML', 'JavaScript', 'Webpack', 'Socket.IO', 'Image Processing', 'Android', 'Git', 'Java Servlet', 'Google API', 'JSP', 'Axios', 'AWS RDS', 'OpenCV', 'MySQL', 'Node.js', 'JWT', 'ReactJS', 'GitHub', 'TypeScript', 'Docker', 'Mongoose']
# ['CSS', 'HTML', 'Django', 'AWS EC2', 'SQLite', 'Google Analytics', 'AWS S3', 'DRF(Django REST framework)', 'jQuery', 'Android', 'Python']
# ['ExpressJS', 'Android', 'Java', 'SQLite', 'Machine Learning', 'Linux', 'Node.js', 'ReactJS', 'OpenCV', 'Docker', 'Jenkins', 'MongoDB', 'Python']
# ['C#', 'ExpressJS', 'Vue.js', '.NET', 'AWS S3', 'Java', 'Node.js', 'AWS EC2', 'ReactJS', 'Passport.js', 'MongoDB', 'GCP(Google Cloud Platform)', 'MySQL']
# ['CSS', 'Python', 'HTML', 'Vue.js', 'REST API', 'Java', 'Node.js', 'Android', 'PHP', 'MongoDB', 'MySQL']
# ['React Native']
# ['REST API', 'Flask', 'Naver Cloud Platform', 'Kubernetes', 'Keras', 'Swift', 'SQLAlchemy', 'Google Cloud Firestore', 'Jupyter', 'Pandas', 'Docker', 'Swagger', 'OpenCV', 'Seaborn', 'Python', 'Google Compute Engine', 'GitHub', 'Tensorflow', 'Google App Engine']
# ['HTML', 'JavaScript', 'Oracle', 'Java', 'JSP', 'Spring']
# ['CSS', 'ExpressJS', 'HTML', 'JavaScript', 'Adobe Photoshop', 'Heroku', 'Node.js', 'JSP', 'Pug', 'MongoDB', 'Mongoose']
# ['Hibernate', 'Ubuntu', 'JSTL', 'Bootstrap', 'Apache Tomcat', 'Apache Kafka', 'JavaScript', 'Netty', 'jQuery', 'Java Servlet', 'centOS', 'Java', 'JSP', 'Apache Struts', 'Spring', 'Oracle WebLogic', 'MySQL', 'ibatis', 'Oracle Database', 'Unix']
# ['Java', 'MySQL']
# ['C#', 'JavaScript', 'Phaser', 'PHP', 'Java', 'Node.js', 'JSP', 'jQuery', 'Socket.IO', 'Raspberry Pi', 'Unity', 'Bootstrap', 'Android', 'MySQL']
# ['Google Firebase Realtime Database', 'HTML', 'Node.js', 'Google Cloud Storage for Firebase', 'Android', 'HTML5']
# ['Gradle', 'Spring Boot', 'Mockito', 'Java', 'Hibernate', 'JUnit', 'Spring', 'Spring Data JPA']
# ['HTML', 'Gradle', 'JavaScript', 'Spring Boot', 'Oracle', 'Java', 'Linux', 'Ajax', 'jQuery', 'Spring', 'Java Persistence API', 'Bootstrap', 'MySQL']
# ['Java', 'HTML', 'Java Servlet', 'MySQL']
# ['AWS S3', 'AWS EC2', 'Chrome Extension', 'ESLint', 'MongoDB', 'GPUImage', 'Parse Server', 'Keras', 'AWS Elastic Beanstalk', 'ExpressJS', 'JavaScript', 'Firebase', 'Swift', 'RxJava', 'AWS CloudWatch', 'Unity', 'Android', 'PHP', 'Java', 'Amazon Web Services(AWS)', 'Babel', 'AWS Lambda', 'AWS CloudFront', 'ES6', 'Python', 'C#', 'MySQL', 'Node.js', 'ReactJS', 'iOS', 'Tensorflow']
# ['HTML', 'JavaScript', 'Java', 'Ajax', 'MySQL', 'jQuery', 'Spring', 'mybatis']
# ['JUnit', 'Bootstrap', 'Apache Tomcat', 'HTML', 'JavaScript', 'Shell Script', 'WebSocket', 'Couchbase', 'Machine Learning', 'Django', 'Mockito', 'Java', 'RabbitMQ', 'JPA(Java Persistent API)', 'Spring', 'Elasticsearch', 'MySQL', 'Spring Boot', 'NLP', 'GitHub']
# ['C#', 'JavaScript', 'Django', 'Java', 'SQLite', 'Selenium', 'GitHub', 'Android', 'Unity', 'Realm', 'Python']
# ['Python', 'Oracle', 'SQL', 'AWS Elastic Load Balancing', 'Swift', 'Ubuntu', 'AWS IAM', 'Redis', 'Docker', 'R', 'MySQL']
# ['HTML', 'JavaScript', 'SQL', 'Java', 'Ajax', 'JSP', 'jQuery', 'GitHub', 'Java Servlet', 'C++']
# ['AWS Elastic Beanstalk', 'AWS Route 53', 'Django', 'AWS EC2', 'Nginx', 'Redis', 'GitHub', 'Docker', 'AWS RDS', 'Git', 'PostgreSQL', 'Python']
# ['CSS', 'HTML', 'JavaScript', 'Oracle', 'Java', 'Linux', 'Node.js', 'jQuery', 'Bootstrap', 'JUnit', 'Apache Subversion(SVN)', 'Spring', 'JIRA', 'MySQL']
# ['HTML', 'JavaScript', 'Spring Data JPA', 'Spring Boot', 'Java', 'Linux', 'Google Geolocation API', 'JSP', 'Bootstrap', 'jQuery', 'Socket.IO', 'MyBatis', 'Google Maps API', 'JPA(Java Persistent API)', 'Spring', 'Jenkins', 'MariaDB', 'MySQL']
# ['WordPress', 'AWS EC2', 'Nginx', 'React Native', 'Bootstrap', 'Apache Tomcat', 'HTML', 'JavaScript', 'AWS Simple Email Service(AWS SES)', 'Ajax', 'Apache Hadoop', 'jQuery', 'Apache Tiles', 'MyBatis', 'Spring Data JPA', 'HTML5', 'AWS Route 53', 'SockJS', 'Java', 'Linux', 'JSP', 'Spring', 'MariaDB', 'AWS Lightsail', 'MySQL', 'Python', '.NET', 'Oracle', 'Spring Boot']
# ['CSS', 'JavaScript', 'Android', 'PHP', 'Oracle', 'Java', 'MVC', 'Ajax', 'JSTL', 'jQuery', 'Apache', 'Apache Struts', 'Spring', 'Apache Tomcat', 'MySQL']
# ['Apache Maven', 'WordPress', 'AWS EC2', 'Redis', 'CSS', 'HTML', 'JavaScript', 'D3.js', 'Apache HTTP Server', 'jQuery', 'PHP', 'Git', 'Java', 'Spring', 'AWS RDS', 'MySQL', 'Python', 'ReactJS', 'XML', 'JIRA']
# ['Apache Maven', 'Ubuntu', 'Bootstrap', 'Apache Tomcat', 'CSS', 'HTML', 'JavaScript', 'Ajax', 'jQuery', 'MyBatis', 'Git', 'Java Servlet', 'Google API', 'Java', 'Linux', 'JSP', 'Naver API', 'Spring', 'AWS RDS', 'Facebook API', 'MySQL', 'GitHub']
# ['C++', 'Java', 'C', 'R', 'Python']
# ['CSS', 'HTML', 'Tableau', 'Java', 'JSP', 'Jupyter', 'Apache Tomcat', 'Google Cloud Tools for Eclipse', 'Python']
# ['HTML', 'Vue.js', 'Sass(SCSS)', 'Linux', 'Webpack', 'jQuery', 'Laravel', 'Bootstrap', 'PHP', 'Git']
# ['AWS S3', 'AWS EC2', 'Ubuntu', 'C', 'JUnit', 'Redis', 'json', 'React Native', 'WebSocket', 'Apache HTTP Server', 'jQuery', 'MyBatis', 'Android', 'Spring Data JPA', 'mybatis', 'Django', 'Java', 'Mockito', 'Linux', 'JSP', 'Raspberry Pi', 'Apache POI', 'Spring', 'AWS RDS', 'AWS Elastic Load Balancing', 'MySQL', 'Python', '공공데이터', 'Arduino', 'Spring Boot', 'SQLite', 'JWT', 'ReactJS', 'Redux.js']
# ['ExpressJS', 'Node.js', 'ReactJS', 'Bootstrap', 'MongoDB']
# ['ExpressJS', 'JavaScript', 'Apache Maven', 'Java', 'Node.js', 'Linux', 'ReactJS', 'styled-components', 'JSP', 'MyBatis', 'Spring', 'Java Servlet', 'MobX', 'MySQL']
# ['MATLAB']
# ['CSS', 'ExpressJS', 'HTML', 'JavaScript', 'Node.js', 'Raspberry Pi', 'MongoDB Atlas', 'PHP', 'Mongoose', 'GCP(Google Cloud Platform)', 'MySQL']
# ['Vue.js', 'Django', 'Node.js', 'Linux', 'ReactJS', 'Naver Cloud Platform', 'Spring', 'Elasticsearch', 'Celery', 'C++']
# ['AWS EC2', 'Node.js', 'Ubuntu', 'Cuckoo Sandbox', 'Raspberry Pi', 'Android', 'Facebook API']
# ['Python', 'PHP', 'AWS S3', 'AWS EC2', 'Java', 'Azure Kinect DK', 'GitHub', 'Apache', 'Tensorflow', 'Android', 'Git', 'MySQL']
# ['C#', 'VR', 'C++', 'Unity', 'OpenCV', 'Python']
# ['Arduino', 'PHP', 'Linux', 'Raspberry Pi', 'C', 'Android', 'MariaDB', 'MySQL']
# ['JavaScript', 'Django', 'Tensorflow', 'Bootstrap', 'Android', 'Python']
# ['AWS EC2', 'Heroku', 'Ubuntu', 'JSTL', 'Google Maps API', 'Bootstrap', 'Passport.js', 'Sequelize.js', 'ExpressJS', 'Ajax', 'jQuery', 'MyBatis', 'EXTJS', 'Git', 'Java', 'Axios', 'Spring', 'Oracle', 'Node.js', 'ReactJS', 'Redux.js', 'Mongoose', 'PostgreSQL']
# ['CSS', 'TF-IDF', 'HTML', 'JavaScript', 'GraphQL', 'Java', 'Node.js', 'ReactJS', 'Flask', 'Raspberry Pi', 'Redis', 'TypeScript', 'Tensorflow', 'Android', 'Tkinter', 'MariaDB', 'Python']
# ['Java', 'Android']
# ['CSS', 'Python', 'HTML', 'JavaScript', 'Spring', 'OpenCV', 'MySQL']
# ['C#', 'Spring Data JPA', 'Spring REST Docs', 'VR', 'Arduino', 'Spring Boot', 'REST API', 'Java', 'C', 'Android', 'Unity', 'T map API', 'PostgreSQL']
# ['YOLO', 'Ubuntu', 'C', 'C++', 'CSS', 'ros', 'HTML', 'JavaScript', 'Machine Learning', 'ARM', 'Django', 'Linux', 'Raspberry Pi', 'OpenCV', 'Python', 'Trello', 'Vue.js', 'Node.js', 'Embedded System', 'ROS', 'GitHub', 'Tensorflow']
# ['ExpressJS', 'MongoDB', 'Node.js', 'Docker']
# ['CSS3', 'C', 'Bootstrap', 'GCP(Google Cloud Platform)', 'CSS', 'ExpressJS', 'HTML', 'JavaScript', 'jQuery', 'Google Cloud Platform', 'Android', 'Google Dialogflow', 'HTML5', 'Java', 'Spring', 'MySQL', 'Kotlin', 'Oracle', 'SQLite', 'Node.js']
# ['Apache Maven', 'ZXing', 'AngularJS', 'MQTT', 'Jenkins', 'Apache Tomcat', 'MongoDB', 'CSS', 'JavaScript', 'Retrofit', 'JDBC(Java Database Connectivity)', 'Ajax', 'jQuery', 'MyBatis', 'Android', 'Git', 'HTML5', 'UML', 'Django', 'Java', 'Apache Ant', 'DRF(Django REST framework)', 'JSP', 'Raspberry Pi', 'Spring', 'Python', 'Spring Boot', 'Oracle', 'SQLite']
# ['JavaScript', 'Spring Security', 'Vue.js', 'GitLab', 'Java', 'jQuery', 'GitHub', 'Apache Subversion(SVN)', 'Azure', 'Bootstrap', 'Git', 'Spring']
# ['Google API', 'DirectX', 'C', 'MFC', 'PHP', 'HTML5', 'C++']
# ['Nginx', 'Ubuntu', 'Glide', 'MongoDB', 'Retrofit', 'RxJava', 'PHP', 'Git', 'Android', 'TCP/IP', 'centOS', 'Java', 'Linux', 'Apache', 'Volley', 'Butter Knife', 'MySQL', 'OkHttp', 'Trello', 'Slack API', 'GitHub', 'WebRTC']
# ['GitLab', 'Django', 'BeautifulSoup', 'Image Processing', 'Tensorflow', 'Spring', 'Jenkins', 'Angular', 'Python']
# ['CSS', 'ExpressJS', 'HTML', 'JavaScript', 'Vue.js', 'Oracle', 'Java', 'Node.js', 'Bootstrap', 'MyBatis', 'Puppeteer', 'Spring', 'Sequelize.js']
# ['C++']
# ['JavaScript', 'Java', 'SQL', 'AngularJS', 'D3.js', 'jQuery', 'Spring', 'Git']
# ['CSS', 'ExpressJS', 'HTML', 'JavaScript', 'Vue.js', 'Sass(SCSS)', 'Linux', 'Google Analytics', 'Node.js', 'AngularJS', 'Java', 'Google Geolocation API', 'jQuery', 'Bootstrap', 'MongoDB', 'MySQL']
# ['ExpressJS', 'JavaScript', 'Java', 'Node.js', 'AngularJS', 'Sass(SCSS)', 'ReactJS', 'MongoDB', 'Oracle Database', 'Mongoose']
# ['CSS', 'HTML', 'JavaScript', 'Travis CI', 'Apache Maven', 'Oracle', 'Java', 'AWS EC2', 'AWS S3', 'jQuery', 'GitHub', 'MyBatis', 'Spring', 'AWS RDS', 'Git', 'AWS CodeDeploy']
# ['Firebase', 'REST API', 'Java', 'Node.js', 'MyBatis', 'Spring', 'Apache Tomcat', 'MongoDB', 'MySQL']
# ['BLE(Bluetooth Low Energy)', 'REST API', 'Java', 'Android', 'Apache Cordova']
# ['WPF', 'NSIS', 'MongoDB', 'Cypress', 'ActionScript', 'MeteorJS', 'Image Processing', 'ARM', 'Linux', 'MSSQL(Microsoft SQL Server)', 'ATL(ATL Transformation Language)', 'Amazon Web Services(AWS)', 'Spring', 'MySQL', 'Python', 'Vue.js', 'Oracle', 'Node.js', 'IOCP']
# ['C#', 'Python', 'Google API', 'JavaScript', 'Node.js', 'MySQL', 'Flask', 'jQuery', 'Unity', 'C++']
# ['Apache Maven', 'REST API', 'C', 'Apache Tomcat', 'C++', 'Keras', 'CSS', 'HTML', 'JavaScript', 'JDBC(Java Database Connectivity)', 'MVC', 'Ajax', 'Image Processing', 'Jupyter', 'Android', 'Java Servlet', 'Java', 'JSP', 'Spring', 'OpenCV', 'ES6', 'MySQL', 'Python', 'Handlebars.js', 'Tensorflow']
# ['C#']
# ['REST API', 'Naver Cloud Platform', 'Bootstrap', 'CSS', 'HTML', 'JavaScript', 'Firebase', 'Ruby', 'Ajax', 'Spring Data JPA', 'Android', 'Java', 'Spring', 'ES6', 'MySQL', 'Trello', 'ReactJS', 'XML', 'Vanilla JS', 'Ruby on Rails']
# ['Git', 'Swift', 'Firebase']
# ['JavaScript', 'Java', 'Docker', 'Spring', 'Jenkins']
# ['CSS', 'HTML', 'JavaScript', 'Java', 'Node.js', 'CodeIgniter', 'Polymer Project', 'jQuery', 'Regular expression', 'Puppeteer', 'Spring', 'PHP', 'EXTJS', 'Apache Flex', 'ES6']
# ['Gradle', 'JavaScript', 'Apache Maven', 'Spring Security', 'Spring Boot', 'Java', 'Ajax', 'JSP', 'jQuery', 'Spring', 'GitHub', 'Bootstrap', 'Spring Data JPA', 'Git', 'Java Servlet', 'MySQL']
# ['Gradle', 'Apache Maven', 'Nginx', 'Redis', 'JUnit', 'ESLint', 'Bootstrap', 'Apache Tomcat', 'web3.js', 'CSS', 'ExpressJS', 'HTML', 'JavaScript', 'AWS Elastic Beanstalk', 'Jest', 'WebSocket', 'Webpack', 'Ajax', 'RxJava', 'jQuery', 'Java Persistence API', 'MyBatis', 'Spring Data JPA', 'Git', 'RxJS', 'SockJS', 'Java', 'Logback', 'JSP', 'Babel', 'Next.js', 'MetaMask', 'Spring', 'i18n', 'ES6', 'MySQL', 'Solidity', 'Spring Boot', 'Tableau', 'Sass(SCSS)', 'Node.js', 'ReactJS', 'Ethereum', 'TypeScript', 'GitHub', 'Yarn', 'Redux.js', 'Apache Subversion(SVN)', 'Enzyme', 'MobX']
# ['AWS EC2', 'Ubuntu', 'React Native', 'Bootstrap', 'CSS', 'HTML', 'JavaScript', 'AWS Simple Email Service(AWS SES)', 'PHP', 'Java Servlet', 'AWS Route 53', 'centOS', 'Java', 'Apache', 'NCP(Naver Cloud Platform)', 'Spring', 'MariaDB', 'Python', 'MySQL']
# ['ExpressJS', 'Vue.js', 'Firebase', 'ReactJS', 'Redux.js', 'Angular5']
# ['Python', 'HTML', 'JavaScript', 'PHP', 'Django', 'Ajax', 'ReactJS', 'AWS Lambda', 'Elasticsearch', 'MySQL']
# ['JavaScript']
# ['C#', 'Java', 'Thymeleaf', 'MyBatis', 'Spring', 'Python']
# ['JavaScript', 'Django', 'SQLite', 'C', 'Python']
# ['REST API', 'Java', 'Ajax', 'Apache Spark', 'Spring', 'Spring Data JPA']
# ['Java', 'Node.js', 'AngularJS', 'Elasticsearch', 'Nginx', 'Apache', 'Apache Tomcat', 'MongoDB', 'MariaDB', 'PostgreSQL']
# ['Java', 'Node.js', 'ReactJS', 'TypeScript', 'Android', 'Unity', 'Sequelize.js']
# ['Heroku', 'Google Maps API', 'React Native', 'Bootstrap', 'Passport.js', 'Sequelize.js', 'CSS', 'ExpressJS', 'HTML', 'JavaScript', 'Jest', 'Socket.IO', 'AR', 'Google API', 'Java', 'Linux', 'Mocha', 'SQL', 'Node.js', 'JWT', 'ReactJS', 'GitHub', 'Redux.js', 'TypeScript', 'PostgreSQL']
# ['CSS', 'Python', 'HTML', 'JavaScript', 'Django', 'Java', 'Oracle', 'Ajax', 'MyBatis', 'Bootstrap', 'Spring']
# ['Spring Data JPA', 'JavaScript', 'Apache Maven', 'Spring Boot', 'Oracle', 'Java', 'Jenkins', 'Netty', 'Redis', 'Docker', 'Spring', 'PHP', 'MySQL']
# ['ExpressJS', 'SockJS', 'Sass(SCSS)', 'Node.js', 'Webpack', 'ReactJS', 'Socket.IO', 'Redux.js', 'Docker', 'MongoDB', 'Mongoose']
# ['CSS', 'JavaScript', 'Vue.js', 'Sass(SCSS)', 'Node.js', 'Webpack', 'AngularJS', 'ReactJS', 'Babel', 'TypeScript', 'Spring', 'Android', 'Apache Cordova']
# ['C#', 'Prolog', 'C++', 'Java', 'Linux', 'MySQL', 'C', 'Lisp', 'PHP', 'Python']
# ['PWA(Progressive Web App)', 'ExpressJS', 'Vue.js', 'Firebase', 'AWS S3', 'Go', 'Jest', 'ReactJS', 'AWS Lambda', 'TypeScript', 'ESLint', 'Prisma', 'AWS API Gateway', 'CircleCI', 'Sketch', 'Vanilla JS', 'ES6']
# ['CSS', 'ExpressJS', 'HTML', 'JavaScript', 'Linux', 'Node.js', 'ReactJS', 'jQuery', 'React Native', 'PHP', 'MySQL']
# ['ExpressJS', 'Django', 'AWS EC2', 'Shell Script', 'Node.js', 'Linux', 'Flask', 'Docker', 'Unity', 'MongoDB', 'PostgreSQL', 'Python']
# ['CSS', 'ExpressJS', 'JavaScript', 'Node.js', 'Kubernetes', 'ReactJS', 'styled-components', 'MeteorJS', 'Redux.js', 'TypeScript', 'Docker', 'Elasticsearch']
# ['Apache Pig', 'Jsoup', 'Nginx', 'Apache Spark', 'GCP(Google Cloud Platform)', 'CSS', 'HTML', 'JavaScript', 'Apache Hadoop', 'Ajax', 'jQuery', 'Git', 'Docker', 'Django', 'MySQL', 'Python', 'GitHub', 'Tensorflow', 'Apache Zeppelin']
# ['ExpressJS', 'JavaScript', 'Node.js', 'AngularJS', 'MongoDB']

# %%
majorstacks_col = []
minorstacks_col = []
companySize_col = []
companystacks_col = []
mystacks_col = []

for i,row in train.iterrows():
    userID = row['userID']
    jobID = row['jobID']
    mystacks = user_tech[userID]
    companystacks = jobs_tags[jobID]
    majorstacks = 0
    minorstack = {}
    minorstacks = 0
    

    
    for stack in mystacks:
        minors = wgraph[stack]
        for sname,weight in minors:
            if sname in minorstack:
                minorstack[sname]+=weight
            else:
                minorstack[sname]=weight
        
        if stack in companystacks:
            majorstacks+=1
    
    minorstack_sorted = sorted(minorstack.items(),key=lambda x:x[1],reverse=True)
    minorstack = []
    for stack in minorstack_sorted:
        if stack[0] not in mystacks:
            minorstack.append(stack[0])
            if len(minorstack)==10:
                break
    
    for stack in minorstack:
        if stack in companystacks:
            minorstacks+=1
    companySize = company_size[job_company[jobID]]
    
    companySize_col.append(companySize)
    majorstacks_col.append(majorstacks)
    minorstacks_col.append(minorstacks)
    mystacks_col.append(len(mystacks))
    companystacks_col.append(len(companystacks))

# %%
train_set = pd.DataFrame({'majorstacks/mystacks':[],'majorstacks/companystacks':[],'companySize':[],
                          'minorstacks/companystacks':[],'majorstacks':[],'minorstacks':[]})
train_set['mystacks'] = mystacks_col
train_set['companystacks'] = companystacks_col
train_set['companySize'] = companySize_col
train_set['majorstacks'] = majorstacks_col
train_set['minorstacks'] = minorstacks_col
train_set['majorstacks/mystacks'] = train_set['majorstacks']/train_set['mystacks']
train_set['majorstacks/companystacks'] = train_set['majorstacks']/train_set['companystacks']
train_set['minorstacks/companystacks'] = train_set['minorstacks']/train_set['companystacks']
train_set['applied'] = train['applied']

train_set.drop('companystacks',axis=1)
# Out:
#       majorstacks/mystacks  majorstacks/companystacks  companySize  \
# 0                 0.000000                   0.000000            2
# 1                 0.040000                   0.333333            3
# 2                 0.142857                   0.333333            0
# 3                 0.176471                   0.600000            2
# 4                 0.050000                   0.250000            2
# ...                    ...                        ...          ...
# 5995              0.068966                   1.000000            2
# 5996              0.120000                   0.500000            2
# 5997              0.142857                   0.166667            3
# 5998              0.142857                   0.250000            2
# 5999              0.037037                   0.250000            3
#
#       minorstacks/companystacks  majorstacks  minorstacks  mystacks  applied
# 0                      0.000000            0            0        13        0
# 1                      0.333333            1            1        25        0
# 2                      0.000000            1            0         7        1
# 3                      0.000000            3            0        17        0
# 4                      0.500000            1            2        20        0
# ...                         ...          ...          ...       ...      ...
# 5995                   0.000000            2            0        29        0
# 5996                   0.333333            3            2        25        0
# 5997                   0.166667            2            2        14        0
# 5998                   0.250000            1            1         7        0
# 5999                   0.250000            1            1        27        0
#
# [6000 rows x 8 columns]

# %%
import numpy as np
X = np.array(pd.DataFrame(train_set, columns=['majorstacks/mystacks','majorstacks/companystacks', 'companySize', 
                                                'minorstacks/companystacks','majorstacks','minorstacks','mystacks']))
y = np.array(pd.DataFrame(train_set, columns=['applied']))

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)

# %%
test = pd.read_csv('data/test_job.csv')
majorstacks_col = []
minorstacks_col = []
companySize_col = []
companystacks_col = []
mystacks_col = []

for i,row in test.iterrows():
    userID = row['userID']
    jobID = row['jobID']
    mystacks = user_tech[userID]
    companystacks = jobs_tags[jobID]
    majorstacks = 0
    minorstack = {}
    minorstacks = 0
    

    
    for stack in mystacks:
        minors = wgraph[stack]
        for sname,weight in minors:
            if sname in minorstack:
                minorstack[sname]+=weight
            else:
                minorstack[sname]=weight
        
        if stack in companystacks:
            majorstacks+=1
    
    minorstack_sorted = sorted(minorstack.items(),key=lambda x:x[1],reverse=True)
    minorstack = []
    for stack in minorstack_sorted:
        if stack[0] not in mystacks:
            minorstack.append(stack[0])
            if len(minorstack)==10:
                break
    
    for stack in minorstack:
        if stack in companystacks:
            minorstacks+=1
    companySize = company_size[job_company[jobID]]
    
    companySize_col.append(companySize)
    majorstacks_col.append(majorstacks)
    minorstacks_col.append(minorstacks)
    mystacks_col.append(len(mystacks))
    companystacks_col.append(len(companystacks))

test_set = pd.DataFrame({'majorstacks/mystacks':[],'majorstacks/companystacks':[],'companySize':[],
                          'minorstacks/companystacks':[],'majorstacks':[],'minorstacks':[]})
test_set['mystacks'] = mystacks_col
test_set['companystacks'] = companystacks_col
test_set['companySize'] = companySize_col
test_set['majorstacks'] = majorstacks_col
test_set['minorstacks'] = minorstacks_col
test_set['majorstacks/mystacks'] = test_set['majorstacks']/test_set['mystacks']
test_set['majorstacks/companystacks'] = test_set['majorstacks']/test_set['companystacks']
test_set['minorstacks/companystacks'] = test_set['minorstacks']/test_set['companystacks']
test_set = test_set.drop('companystacks',axis=1)
test_set.head()
# Out:
#    majorstacks/mystacks  majorstacks/companystacks  companySize  \
# 0              0.230769                   0.428571            2
# 1              0.083333                   0.142857            2
# 2              0.166667                   0.142857            2
# 3              0.000000                   0.000000            2
# 4              0.000000                   0.000000            2
#
#    minorstacks/companystacks  majorstacks  minorstacks  mystacks
# 0                   0.142857            3            1        13
# 1                   0.142857            1            1        12
# 2                   0.142857            1            1         6
# 3                   0.000000            0            0         5
# 4                   0.666667            0            4        11

# %%
import collections
test_X = np.array(pd.DataFrame(test_set, columns=['majorstacks/mystacks','majorstacks/companystacks', 'companySize', 
                                                'minorstacks/companystacks','majorstacks','minorstacks','mystacks']))
prediction = dtree.predict(test_X)
collections.Counter(prediction)
result = pd.DataFrame({'applied':prediction})
result.to_csv('predict.csv',index=False)

# %%
feature_names = train_set.columns.tolist()
feature_names = feature_names[0:4]
target_name = np.array(['apllied No', 'applied Yes'])
dt_dot_data = dtree.export_graphviz(dt_clf, out_file = None,
                                  feature_names = feature_names,
                                  class_names = target_name,
                                  filled = True, rounded = True,
                                  special_characters = True)
dt_graph = pydotplus.graph_from_dot_data(dt_dot_data)
Image(dt_graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-39e14a3147e9> in <module>
#       2 feature_names = feature_names[0:4]
#       3 target_name = np.array(['apllied No', 'applied Yes'])
# ----> 4 dt_dot_data = dtree.export_graphviz(dt_clf, out_file = None,
#       5                                   feature_names = feature_names,
#       6                                   class_names = target_name,
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'export_graphviz'
